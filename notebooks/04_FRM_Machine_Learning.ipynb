# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
# Load data in numpy array
data = np.load('../data/data_pca_50_target.npz')
data.files
# Out:
# ['arr_0', 'arr_1']

# %%
data.allow_pickle = True

# %%
X = data['arr_0'] # pca data with 50 components
y = data['arr_1'] # target or dependent variables

# %%
X.shape, y.shape
# Out:
# ((4322, 50), (4322,))

# %% [markdown]
# ### Split the data into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3457, 50) (865, 50) (3457,) (865,)

# %% [markdown]
# ### Training a model

# %%
model_svc = SVC(probability=True)

param_grid = {
    'C': [0.5, 1, 10, 20, 30, 50],
    'kernel': ['rbf', 'poly'],
    'gamma': [0.1, 0.05, 0.001, 0.002, 0.005],
    'coef0': [0, 1]
}

# %%
model_grid = GridSearchCV(model_svc, param_grid=param_grid, scoring='accuracy', cv=3, verbose=2)

# %%
model_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   2.3s
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   2.2s
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   2.2s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.6s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.9s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.5s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   1.8s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   2.2s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   2.2s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.7s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.5s
# ...
